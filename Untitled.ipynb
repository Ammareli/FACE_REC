# %%
pip list
# Out:
# Package                      Version
# ---------------------------- ------------
# absl-py                      2.0.0
# anyio                        4.0.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# async-lru                    2.0.4
# attrs                        23.1.0
# Babel                        2.13.1
# beautifulsoup4               4.12.2
# bleach                       6.1.0
# build                        1.0.3
# cachetools                   5.3.2
# certifi                      2023.7.22
# cffi                         1.16.0
# charset-normalizer           3.3.2
# cmake                        3.27.7
# colorama                     0.4.6
# comm                         0.1.4
# contourpy                    1.1.1
# cvzone                       1.6.1
# cycler                       0.12.1
# debugpy                      1.8.0
# ...

# %%
import tensorflow as tf

# %%
from tensorflow.image import
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from tnsorflow.keras import images
#
# ModuleNotFoundError: No module named 'tnsorflow'
